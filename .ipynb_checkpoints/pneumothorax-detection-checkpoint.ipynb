# %%
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Bidirectional, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, K, Reshape, LSTM, CuDNNLSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import sklearn
import cv2
import scipy
import os
import sys
import csv
import matplotlib.pyplot as plt
# %matplotlib inline
import pydicom
import tqdm
#Torch
import torch.nn as nn

print(os.listdir("../input/"))

# Any results you write to the current directory are saved as output.
# Out:
# Using TensorFlow backend.
# ['siimdicom', 'siim-acr-pneumothorax-segmentation']

# %% [markdown]
# Pre-Process (Structure data appropriately for Stage 1)

# %%
import glob

train_path = '../input/siimdicom/train-3/train-3/*/*/*.dcm'
test_path = '../input/siimdicom/test/test/*/*/*.dcm'

train_set = glob.glob(train_path)[:5000]
test_set = glob.glob(test_path)[:5000]

df_half = pd.read_csv('../input/siimdicom/train-rle.csv', index_col='ImageId')

# %%
print('The training set is of size ' + str(len(train_set)) + '.')
print('The testing set is of size ' + str(len(test_set)) + '.')
# Out:
# The training set is of size 5000.
# The testing set is of size 1377.

# %%
def show_dicom_meta(data):
    print("Filename.........:", file_path)
    print("Storage type.....:", data.SOPClassUID)
    print()

    patient_name = data.PatientName
    display_name = patient_name
    print("Patient's name......:", display_name)
    print("Patient id..........:", data.PatientID)
    print("Patient's Age.......:", data.PatientAge)
    print("Patient's Sex.......:", data.PatientSex)
    print("Modality............:", data.Modality)
    print("Body Part Examined..:", data.BodyPartExamined)
    print("View Position.......:", data.ViewPosition)
    
    if 'PixelData' in data:
        rows = int(data.Rows)
        cols = int(data.Columns)
        print("Image size.......: {rows:d} x {cols:d}, {size:d} bytes".format(
            rows=rows, cols=cols, size=len(data.PixelData)))
        if 'PixelSpacing' in data:
            print("Pixel spacing....:", data.PixelSpacing)

def plot_dicom_img(data, figsize=(10,10)):
    plt.figure(figsize=figsize)
    plt.imshow(data.pixel_array, cmap=plt.cm.bone)
    plt.show()

# %%
file_path = train_set[13]

data = pydicom.dcmread(file_path)
show_dicom_meta(data)
plot_dicom_img(data)
# Out:
# Filename.........: ../input/siimdicom/train-3/train-3/1.2.276.0.7230010.3.1.2.8323329.11144.1517875231.391276/1.2.276.0.7230010.3.1.3.8323329.11144.1517875231.391275/1.2.276.0.7230010.3.1.4.8323329.11144.1517875231.391277.dcm
# Storage type.....: 1.2.840.10008.5.1.4.1.1.7
#
# Patient's name......: b51745d3-d346-4cf9-aaa4-11b2b92fb4b9
# Patient id..........: b51745d3-d346-4cf9-aaa4-11b2b92fb4b9
# Patient's Age.......: 18
# Patient's Sex.......: M
# Modality............: CR
# Body Part Examined..: CHEST
# View Position.......: PA
# Image size.......: 1024 x 1024, 142604 bytes
# Pixel spacing....: ['0.14300000000000002', '0.14300000000000002']

# %%
# Generating training images and masks from dataset

img_height = 1024
img_width = 1024
img_channel = 1

# Get train images and masks
X_train = np.zeros((len(train_set), img_height, img_width, img_channel), dtype=np.uint8)
Y_train = np.zeros((len(train_set), img_height, img_width, 1), dtype=np.bool)

print('Retrieving training images and masks ... ')
sys.stdout.flush()

# rle2mask credit to: https://www.kaggle.com/freeman89/eda-can-you-see-the-pneumothorax

def rle2mask(rle, width, height):
    mask= np.zeros(width * height)
    array = np.asarray([int(x) for x in rle.split()])
    starts = array[0::2]
    lengths = array[1::2]
    current_position = 0
    for index, start in enumerate(starts):
        current_position += start
        mask[current_position:current_position+lengths[index]] = 255
        current_position += lengths[index]
    return mask.reshape(width, height)

# Original source code credit to: https://www.kaggle.com/jesperdramsch/intro-chest-xray-dicom-viz-u-nets-full-data 
# Code has been adapted hence discrepancies.

for n, _id in tqdm.tqdm_notebook(enumerate(train_set), total=len(train_set)):
    train_data = pydicom.read_file(_id)
    X_train[n] = np.expand_dims(train_data.pixel_array, axis=2)
    try:
        if '-1' in df_half.loc[_id.split('/')[-1][:-4],' EncodedPixels']:
            Y_train[n] = np.zeros((1024, 1024, 1))
        else:
            if type(df_half.loc[_id.split('/')[-1][:-4],' EncodedPixels']) == str:
                Y_train[n] = np.reshape(rle2mask(df_half.loc[_id.split('/')[-1][:-4],' EncodedPixels'], 1024, 1024), \
                                        (1024, 1024, 1))
            else:
                Y_train[n] = np.zeros((1024, 1024, 1))
                for x in df_half.loc[_id.split('/')[-1][:-4],' EncodedPixels']:
                    Y_train[n] =  Y_train[n] + np.reshape(rle2mask(x, 1024, 1024), (1024, 1024, 1))
    except KeyError:
        print(f"Key {_id.split('/')[-1][:-4]} is without mask; hence assume subject is without pneumothorax.")
        Y_train[n] = np.zeros((1024, 1024, 1)) # Assume missing masks are empty masks.

print('Completed retreival of all training images and masks.')
# Out:
# Retrieving training images and masks ...
# HBox(children=(IntProgress(value=0, max=5000), HTML(value='')))
# Key 1.2.276.0.7230010.3.1.4.8323329.10231.1517875222.737143 is without mask; hence assume subject is without pneumothorax.
# Key 1.2.276.0.7230010.3.1.4.8323329.2630.1517875173.773726 is without mask; hence assume subject is without pneumothorax.
# Key 1.2.276.0.7230010.3.1.4.8323329.3321.1517875177.247887 is without mask; hence assume subject is without pneumothorax.
# Key 1.2.276.0.7230010.3.1.4.8323329.3089.1517875176.36192 is without mask; hence assume subject is without pneumothorax.
# Key 1.2.276.0.7230010.3.1.4.8323329.32688.1517875161.809571 is without mask; hence assume subject is without pneumothorax.
# Key 1.2.276.0.7230010.3.1.4.8323329.31801.1517875156.929061 is without mask; hence assume subject is without pneumothorax.
# Key 1.2.276.0.7230010.3.1.4.8323329.2083.1517875171.71387 is without mask; hence assume subject is without pneumothorax.
# Key 1.2.276.0.7230010.3.1.4.8323329.13415.1517875245.218707 is without mask; hence assume subject is without pneumothorax.
# Key 1.2.276.0.7230010.3.1.4.8323329.3352.1517875177.433385 is without mask; hence assume subject is without pneumothorax.
# Key 1.2.276.0.7230010.3.1.4.8323329.12062.1517875237.179186 is without mask; hence assume subject is without pneumothorax.
# Key 1.2.276.0.7230010.3.1.4.8323329.13620.1517875246.884737 is without mask; hence assume subject is without pneumothorax.
# Key 1.2.276.0.7230010.3.1.4.8323329.1068.1517875166.144255 is without mask; hence assume subject is without pneumothorax.
# Key 1.2.276.0.7230010.3.1.4.8323329.11557.1517875233.601090 is without mask; hence assume subject is without pneumothorax.
# Key 1.2.276.0.7230010.3.1.4.8323329.14557.1517875252.690062 is without mask; hence assume subject is without pneumothorax.
# Key 1.2.276.0.7230010.3.1.4.8323329.4843.1517875185.73985 is without mask; hence assume subject is without pneumothorax.
# Key 1.2.276.0.7230010.3.1.4.8323329.13378.1517875244.961609 is without mask; hence assume subject is without pneumothorax.
# Key 1.2.276.0.7230010.3.1.4.8323329.3791.1517875179.436805 is without mask; hence assume subject is without pneumothorax.
# Key 1.2.276.0.7230010.3.1.4.8323329.10599.1517875224.488727 is without mask; hence assume subject is without pneumothorax.
# Key 1.2.276.0.7230010.3.1.4.8323329.2563.1517875173.431928 is without mask; hence assume subject is without pneumothorax.
#
# Completed retreival of all training images and masks.

# %%
X_train.shape
# Out:
# (5000, 1024, 1024, 1)

# %%
Y_train.shape
# Out:
# (5000, 1024, 1024, 1)

# %%
# Testing images

test_img = X_train[13].reshape(1024, 1024)

plt.figure(figsize=(10, 10))
plt.imshow(test_img, cmap=plt.cm.bone)
plt.show()

# %%
# Testing masks

test_mask = Y_train[13].reshape(1024, 1024).T

print(np.sum(test_mask))

plt.figure(figsize=(10, 10))
plt.imshow(test_mask, cmap=plt.cm.bone)
plt.show()
# Out:
# 15488

# %%
start = 13  # Start index of images
num_img = 5  # Total number of images to show

fig, ax = plt.subplots(nrows=1, ncols=num_img, sharey=True, figsize=(10,10))
for i, img_file in enumerate(X_train[start:start+num_img]):
    for j, mask_file in enumerate(Y_train[start:start+num_img]):
        img = img_file.reshape(1024, 1024)
        if j == i:
            mask = mask_file.reshape(1024, 1024).T
            ax[i].imshow(img, cmap=plt.cm.bone)
            ax[i].imshow(mask, alpha=0.3, cmap="Reds")
            if np.sum(mask) == 0:
                ax[i].set_title('Nothing to show.')
            elif np.sum(mask) > 0:
                ax[i].set_title('Please see marker.')

# %%
#AlexNet
class AlexNet(nn.Module):
    """
        AlexNet architecture responsible of extracting image features
        from FC7 after ReLU

        output: 4096-d feature vector
    """

    def __init__(self):
        super(AlexNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.avgpool = nn.AdaptiveAvgPool2d((6, 6))
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
        )

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = x.view(x.size(0), 256 * 6 * 6)
        x = self.classifier(x)
        return x

# %% [markdown]
# Yolo (Faster R-CNN is preferred) for object detection Use cuDNN for optimization

# %% [markdown]
# Pre-process to feed image into DL models

# %% [markdown]
# Selection of CNNs- Train and test different CNNs (VGG16, VGG19, Inceptionv3, and Resnet50). We can also test for 3D-CNNs. Using U-Net can also be tested. I do not recommend using Capsule Networks as we have never coded it, neither could I find a good reference.

# %% [markdown]
# Output and Verification as per the contest requirements
